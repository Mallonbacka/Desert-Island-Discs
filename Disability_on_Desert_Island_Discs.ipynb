# %% [markdown]
# In the terminal, before starting:
#
# ```
# pip install wikipedia
# pip install --force-reinstall openpyxl
# ```

# %% [markdown]
# ## Libraries
#
# Let's start with the basic dependencies.

# %%
import pandas as pd
import numpy
import wikipedia

# %% [markdown]
# ## Get the data
#
# Now import the spreadsheet. The code is based on https://alan-turing-institute.github.io/TuringDataStories-fastpages/data%20exploration/data%20wrangling/data%20visualisation/digital%20humanities/2022/03/09/Desert-Island-Discs.html
#
# I'm using the version of the spreadsheet that includes Wikipedia links, so I don't have to take care of disambiguation on my own. This means the most recent episodes are not included.

# %%
hc_data_url = (
    "https://hcommons.org/deposits/download/hc:42512/CONTENT/desert_island_discs.xlsx"
 )

castaways_df = pd.read_excel(
    hc_data_url,
    sheet_name="castaways",
    parse_dates=["date", "date_of_birth"],
    index_col=0
)
castaways_df["year"] = [i.year for i in castaways_df["date"].dt.date]
castaways_df.head(1)
# Out:
#    episode_ref       date  castaway_ref        name    std_name gender  \
# 0         2828 1942-01-29          2855  Vic Oliver  vic oliver   male
#
#                                           profession country_of_citizenship  \
# 0  ['actor', 'performing artist', 'artist', 'prof...        Austria-Hungary
#
#   place_of_birth country_of_birth date_of_birth  favTrack luxury book  \
# 0         Vienna          Austria    1898-07-08  NA by NA    NaN  NaN
#
#                                   wiki_link  \
# 0  https://en.wikipedia.org/wiki/Vic_Oliver
#
#                                         link  year
# 0  https://www.bbc.co.uk/programmes/p009y0nq  1942

# %% [markdown]
# # Get the Wikipedia Categories
#
# For each one, let's open the Wikipedia article and make a big list of categories.

# %%
castaways_df['wiki_id'] = castaways_df['wiki_link'].replace('https://en.wikipedia.org/wiki/', '', regex=True)
castaways_df.head(1)
# Out:
#    episode_ref       date  castaway_ref        name    std_name gender  \
# 0         2828 1942-01-29          2855  Vic Oliver  vic oliver   male
#
#                                           profession country_of_citizenship  \
# 0  ['actor', 'performing artist', 'artist', 'prof...        Austria-Hungary
#
#   place_of_birth country_of_birth date_of_birth  favTrack luxury book  \
# 0         Vienna          Austria    1898-07-08  NA by NA    NaN  NaN
#
#                                   wiki_link  \
# 0  https://en.wikipedia.org/wiki/Vic_Oliver
#
#                                         link  year     wiki_id
# 0  https://www.bbc.co.uk/programmes/p009y0nq  1942  Vic_Oliver

# %%
all_categories = set()
for page_id in castaways_df['wiki_id']:
    try:
        if pd.isna(page_id):
            continue
        page = wikipedia.page(page_id, auto_suggest = False)
        all_categories.update(page.categories)
    except Exception as e:
        continue
# Out:
# /opt/conda/lib/python3.10/site-packages/wikipedia/wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /opt/conda/lib/python3.10/site-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')

# %%
pd.Series(list(all_categories)).sort_values().to_csv("categories.csv")

# %% [markdown]
# Next, I manually choose the categories that should select for disabled interviewees.
#
# More on the thinking here in the blog post, but I end up with `included_categories.csv`.

# %% [markdown]
# ## Get the Matching People

# %% [markdown]
# First, let's import the included categories:

# %%
included_categories_csv = pd.read_csv("included_categories.csv")
included_categories = set(included_categories_csv["category"])

# %%
disability_column = []
for page_id in castaways_df['wiki_id']:
    try:
        if pd.isna(page_id):
            disability_column.append(None)
            continue
        page = wikipedia.page(page_id, auto_suggest = False)
        if included_categories.intersection(set(page.categories)):
            print(page.title)
            disability_column.append(True)
        else:
            disability_column.append(False)
        
    except Exception as e:
        disability_column.append(None)
        continue
# Out:
# Eric Sykes
# /opt/conda/lib/python3.10/site-packages/wikipedia/wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /opt/conda/lib/python3.10/site-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# Wee Georgie Wood
# George Shearing
# Michael Flanders
# David Hockney
# Michael Ansell
# Barry Humphries
# Itzhak Perlman
# David Scott Blackhall
# Tristan Jones
# Richard Leakey
# Douglas Bader
# Rosemary Sutcliff
# Christopher Reeve
# Ved Mehta
# Anthony Hopkins
# Bobby Robson
# Stephanie Beacham
# David Blunkett
# Sue Townsend
# Stephen Hawking
# Evelyn Glennie
# Jack Ashley, Baron Ashley of Stoke
# Oliver Sacks
# John Wilson (blind activist)
# Gordon Brown
# Eric Sykes
# Ian Dury
# Tanni Grey-Thompson
# Bobby Robson
# Frank Gardner (journalist)
# Thomas Quasthoff
# Barry Humphries
# Jane Campbell, Baroness Campbell of Surbiton
# Ade Adepitan
# Chris Packham
# Yinka Shonibare
# Warwick Davis
# Philip Craven

# %%
castaways_df["disability_status"] = disability_column

# %%
disabled_castaways = castaways_df[castaways_df["disability_status"] == True]
disabled_castaways.head()
# Out:
#       episode_ref       date  castaway_ref              name  \
# 362          2954 1957-12-09           852        Eric Sykes
# 562          2608 1961-11-06          2893  Wee Georgie Wood
# 613          2558 1962-11-05           985   George Shearing
# 769          2396 1965-12-27          1850  Michael Flanders
# 1082         2080 1972-02-07           603     David Hockney
#
#               std_name gender  \
# 362         eric sykes   male
# 562   wee georgie wood   male
# 613    george shearing   male
# 769   michael flanders   male
# 1082     david hockney   male
#
#                                              profession  \
# 362   ['screenwriter', 'writer', 'author', 'creator'...
# 562   ['comedian', 'actor', 'performing artist', 'ar...
# 613   ['composer', 'musician', 'artist', 'profession...
# 769   ['actor', 'performing artist', 'artist', 'prof...
# 1082  ['painter', 'visual artist', 'artist', 'profes...
#
#      country_of_citizenship place_of_birth country_of_birth date_of_birth  \
# 362          United Kingdom         Oldham   United Kingdom    1923-05-04
# 562                     NaN            NaN              NaN    1894-12-17
# 613          United Kingdom         London     Roman Empire    1919-08-13
# 769          United Kingdom         London     Roman Empire    1922-03-01
# 1082                England       Bradford   United Kingdom    1937-07-09
#
#                                                favTrack  \
# 362                                            NA by NA
# 562   Private Lives Act 1 by Noel Coward & Gertrude ...
# 613   Cantata No. 54: Widerstehe doch der S√ºnde by ...
# 769   Sanctus / Agnus Dei from Missa Criolla by Arie...
# 1082          Liebestod (from Tristan und Isolde) by NA
#
#                                                luxury  \
# 362                                               NaN
# 562                                 Writing materials
# 613                            Metal construction set
# 769                                              Horn
# 1082  Paper, pencils and a battery-operated sharpener
#
#                                          book  \
# 362                                       NaN
# 562   Memoirs of a Midget - Walter de la Mare
# 613       Masterman Ready - Frederick Marryat
# 769                    Blank book and pencils
# 1082                  Route 69 - Floyd Carter
#
#                                            wiki_link  \
# 362         https://en.wikipedia.org/wiki/Eric_Sykes
# 562   https://en.wikipedia.org/wiki/Wee_Georgie_Wood
# 613    https://en.wikipedia.org/wiki/George_Shearing
# 769   https://en.wikipedia.org/wiki/Michael_Flanders
# 1082     https://en.wikipedia.org/wiki/David_Hockney
#
#                                            link  year           wiki_id  \
# 362   https://www.bbc.co.uk/programmes/p009y8l4  1957        Eric_Sykes
# 562   https://www.bbc.co.uk/programmes/p009y6ck  1961  Wee_Georgie_Wood
# 613   https://www.bbc.co.uk/programmes/p009y5t1  1962   George_Shearing
# 769   https://www.bbc.co.uk/programmes/p009y3r8  1965  Michael_Flanders
# 1082  https://www.bbc.co.uk/programmes/p009nc50  1972     David_Hockney
#
#      disability_status
# 362               True
# 562               True
# 613               True
# 769               True
# 1082              True

# %%
disabled_castaways.to_csv("disabled_castaways.csv")

# %% [markdown]
# Finally, let's get the core data into Markdown ready to use in the blog.
#
# I'll edit it manually for readability before publishing.

# %%
for i in disabled_castaways.index:
    castaway_id = disabled_castaways.loc[i]["wiki_id"]
    page = wikipedia.page(castaway_id, auto_suggest = False)
    episode_url = disabled_castaways.loc[i]["link"]
    print("- **{}** ({}) - ".format(page.title, disabled_castaways.loc[i]["year"]))
    print(wikipedia.summary(castaway_id, sentences = 1, auto_suggest = False))
    print("[{} on Wikipedia]({}), [{} on Desert Island Discs]({}), ".format(page.title, page.url, page.title, episode_url))
# Out:
# - **Eric Sykes** (1957) -
# Eric Sykes  (4 May 1923 – 4 July 2012) was an English radio, stage, television and film writer, comedian, actor, and director whose performing career spanned more than 50 years.
# [Eric Sykes on Wikipedia](https://en.wikipedia.org/wiki/Eric_Sykes), [Eric Sykes on Desert Island Discs](https://www.bbc.co.uk/programmes/p009y8l4),
# - **Wee Georgie Wood** (1961) -
# George Wood Bamlett OBE (17 December 1895 – 19 February 1979), known professionally as Wee Georgie Wood, was a British comic entertainer and actor who appeared in films, plays and music hall revues.
# [Wee Georgie Wood on Wikipedia](https://en.wikipedia.org/wiki/Wee_Georgie_Wood), [Wee Georgie Wood on Desert Island Discs](https://www.bbc.co.uk/programmes/p009y6ck),
# - **George Shearing** (1962) -
# Sir George Albert Shearing,  (13 August 1919 –  14 February 2011) was a British jazz pianist who for many years led a popular jazz group that recorded for Discovery Records, MGM Records and Capitol Records.
# [George Shearing on Wikipedia](https://en.wikipedia.org/wiki/George_Shearing), [George Shearing on Desert Island Discs](https://www.bbc.co.uk/programmes/p009y5t1),
# - **Michael Flanders** (1965) -
# Michael Henry Flanders  (1 March 1922 – 14 April 1975) was an English actor, broadcaster, and writer and performer of comic songs.
# [Michael Flanders on Wikipedia](https://en.wikipedia.org/wiki/Michael_Flanders), [Michael Flanders on Desert Island Discs](https://www.bbc.co.uk/programmes/p009y3r8),
# - **David Hockney** (1972) -
# David Hockney  (born 9 July 1937) is an English painter, draftsman, printmaker, stage designer, and photographer.
# [David Hockney on Wikipedia](https://en.wikipedia.org/wiki/David_Hockney), [David Hockney on Desert Island Discs](https://www.bbc.co.uk/programmes/p009nc50),
# - **Michael Ansell** (1973) -
# Colonel Sir Michael Picton Ansell, CBE, DSO (26 March 1905 – 17 February 1994) was a soldier, show jumping rider, polo player, and horse show administrator.
# [Michael Ansell on Wikipedia](https://en.wikipedia.org/wiki/Michael_Ansell), [Michael Ansell on Desert Island Discs](https://www.bbc.co.uk/programmes/p009n8t9),
# - **Barry Humphries** (1973) -
# John Barry Humphries  (born 17 February 1934) is an Australian comedian, actor, author and satirist.
# [Barry Humphries on Wikipedia](https://en.wikipedia.org/wiki/Barry_Humphries), [Barry Humphries on Desert Island Discs](https://www.bbc.co.uk/programmes/p009n8cn),
# - **Itzhak Perlman** (1978) -
# Itzhak Perlman (Hebrew: יצחק פרלמן; born August 31, 1945) is an Israeli-American violinist widely considered one of the greatest violinists in the world.
# [Itzhak Perlman on Wikipedia](https://en.wikipedia.org/wiki/Itzhak_Perlman), [Itzhak Perlman on Desert Island Discs](https://www.bbc.co.uk/programmes/p009mysv),
# - **David Scott Blackhall** (1980) -
# David Scott Blackhall was a radio personality, author and poet.
# [David Scott Blackhall on Wikipedia](https://en.wikipedia.org/wiki/David_Scott_Blackhall), [David Scott Blackhall on Desert Island Discs](https://www.bbc.co.uk/programmes/p009mw1h),
# - **Tristan Jones** (1980) -
# Arthur Jones, pen name Tristan Jones (8 May 1929 – 21 June 1995) was a British mariner and author.
# [Tristan Jones on Wikipedia](https://en.wikipedia.org/wiki/Tristan_Jones), [Tristan Jones on Desert Island Discs](https://www.bbc.co.uk/programmes/p009mvz0),
# - **Richard Leakey** (1981) -
# Richard Erskine Frere Leakey  (19 December 1944 – 2 January 2022) was a Kenyan paleoanthropologist, conservationist and politician.
# [Richard Leakey on Wikipedia](https://en.wikipedia.org/wiki/Richard_Leakey), [Richard Leakey on Desert Island Discs](https://www.bbc.co.uk/programmes/p009mv29),
# - **Douglas Bader** (1981) -
# Group Captain Sir Douglas Robert Steuart Bader,  (; 21 February 1910 – 5 September 1982) was a Royal Air Force flying ace during the Second World War.
# [Douglas Bader on Wikipedia](https://en.wikipedia.org/wiki/Douglas_Bader), [Douglas Bader on Desert Island Discs](https://www.bbc.co.uk/programmes/p009mthn),
# - **Rosemary Sutcliff** (1983) -
# Rosemary Sutcliff  (14 December 1920 – 23 July 1992) was an English novelist best known for children's books, especially historical fiction and retellings of myths and legends.
# [Rosemary Sutcliff on Wikipedia](https://en.wikipedia.org/wiki/Rosemary_Sutcliff), [Rosemary Sutcliff on Desert Island Discs](https://www.bbc.co.uk/programmes/p009mj4y),
# - **Christopher Reeve** (1984) -
# Christopher D'Olier Reeve (September 25, 1952 – October 10, 2004) was an American actor, film director, author, and activist, best known for playing the title character in the film Superman (1978) and three sequels.
# [Christopher Reeve on Wikipedia](https://en.wikipedia.org/wiki/Christopher_Reeve), [Christopher Reeve on Desert Island Discs](https://www.bbc.co.uk/programmes/p009mhk0),
# - **Ved Mehta** (1984) -
# Ved Parkash Mehta (21 March 1934 – 9 January 2021) was an Indian-born writer who lived and worked mainly in the United States.
# [Ved Mehta on Wikipedia](https://en.wikipedia.org/wiki/Ved_Mehta), [Ved Mehta on Desert Island Discs](https://www.bbc.co.uk/programmes/p009mh8b),
# - **Anthony Hopkins** (1985) -
# Sir Philip Anthony Hopkins  (born 31 December 1937) is a Welsh actor, director, and producer.
# [Anthony Hopkins on Wikipedia](https://en.wikipedia.org/wiki/Anthony_Hopkins), [Anthony Hopkins on Desert Island Discs](https://www.bbc.co.uk/programmes/p009mn5s),
# - **Bobby Robson** (1986) -
# Sir Robert William Robson  (18 February 1933 – 31 July 2009) was an English footballer and football manager.
# [Bobby Robson on Wikipedia](https://en.wikipedia.org/wiki/Bobby_Robson), [Bobby Robson on Desert Island Discs](https://www.bbc.co.uk/programmes/p009mmml),
# - **Stephanie Beacham** (1988) -
# Stephanie Beacham (born 28 February 1947) is an English television, film, radio and theatre actress.
# [Stephanie Beacham on Wikipedia](https://en.wikipedia.org/wiki/Stephanie_Beacham), [Stephanie Beacham on Desert Island Discs](https://www.bbc.co.uk/programmes/p009mgcr),
# - **David Blunkett** (1990) -
# David Blunkett, Baron Blunkett,  (born 6 June 1947) is a British Labour Party politician who has been a Member of the House of Lords since 2015, and previously served as the Member of Parliament (MP) for  Sheffield Brightside and Hillsborough from  1987 to 2015, when he stood down.
# [David Blunkett on Wikipedia](https://en.wikipedia.org/wiki/David_Blunkett), [David Blunkett on Desert Island Discs](https://www.bbc.co.uk/programmes/p009406m),
# - **Sue Townsend** (1991) -
# Susan Lillian Townsend  (née Johnstone; 2 April 1946 – 10 April 2014), was an English writer and humorist whose work encompasses novels, plays and works of journalism.
# [Sue Townsend on Wikipedia](https://en.wikipedia.org/wiki/Sue_Townsend), [Sue Townsend on Desert Island Discs](https://www.bbc.co.uk/programmes/p0